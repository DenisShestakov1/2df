# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.metrics import silhouette_score


df = pd.read_csv("/content/weight-height.csv")
print(df)

df["Gender"] = df["Gender"].map({"Male": 1, "Female": 0})
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
df["Weight"] *= 0.453592

df["Height"] *= 2.54

male_df = df[df["Gender"] == 1]
female_df = df[df["Gender"] == 0]
print("Мужчины:")
print(male_df.head())
print("\nЖенщины:")
print(female_df.head())
# Out:
# Мужчины:
#    Gender      Height      Weight
# 0       1  187.571423  109.720985
# 1       1  174.706036   73.622732
# 2       1  188.239668   96.497550
# 3       1  182.196685   99.809504
# 4       1  177.499761   93.598619
#
# Женщины:
#       Gender      Height     Weight
# 5000       0  149.633259  46.306448
# 5001       0  165.684232  64.095191
# 5002       0  160.957270  59.439332
# 5003       0  163.779193  58.137572
# 5004       0  156.954464  58.867808

# %%
male_df.plot(kind='bar', y=['Height', 'Weight'], title='Male Distribution', figsize=(10, 6))
plt.xlabel('Index')
plt.ylabel('Value')
plt.show()

female_df.plot(kind='bar', y=['Height', 'Weight'], title='Female Distribution', figsize=(10, 6))
plt.xlabel('Index')
plt.ylabel('Value')
plt.show()

# %%
kmeans = KMeans(n_clusters=2)
kmeans.fit(df[['Height', 'Weight']])
df['KMeans_Cluster'] = kmeans.labels_


agglomerative = AgglomerativeClustering(n_clusters=2)
agglomerative.fit(df[['Height', 'Weight']])
df['Agglomerative_Cluster'] = agglomerative.labels_


print(df)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#       Gender      Height      Weight  KMeans_Cluster  Agglomerative_Cluster
# 0          1  187.571423  109.720985               0                      0
# 1          1  174.706036   73.622732               0                      0
# 2          1  188.239668   96.497550               0                      0
# 3          1  182.196685   99.809504               0                      0
# 4          1  177.499761   93.598619               0                      0
# ...      ...         ...         ...             ...                    ...
# 9995       0  168.078536   62.041159               1                      1
# 9996       0  170.350573   77.504315               0                      0
# 9997       0  162.224700   58.275377               1                      1
# 9998       0  175.346978   74.322166               0                      0
# 9999       0  157.338385   51.550324               1                      1
#
# [10000 rows x 5 columns]

# %%
kmeans_silhouette = silhouette_score(df[['Height', 'Weight']], kmeans.labels_)# Вычисление коэффициента силуэта для кластеризации методом k-средних
print("KMeans оценка:", kmeans_silhouette)

agglomerative_silhouette = silhouette_score(df[['Height', 'Weight']], agglomerative.labels_)# Вычисление коэффициента силуэта для иерархической кластеризации
print("Agglomerative оценка:", agglomerative_silhouette)
# Out:
# KMeans Silhouette Score: 0.5707415055160001
# Agglomerative Silhouette Score: 0.5264617638310783
